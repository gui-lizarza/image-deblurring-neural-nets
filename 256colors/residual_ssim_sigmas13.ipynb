# %%
import tensorflow as tf

# %%
# adaptations for running Tensorflow on GeForce RTX 2080
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:1 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce RTX 2080, pci bus id: 0000:01:00.0, compute capability: 7.5
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: GeForce RTX 2080, pci bus id: 0000:02:00.0, compute capability: 7.5

# %%
tf.test.is_gpu_available()
# Out:
# True

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Activation, Conv2D, Add, BatchNormalization

# %%
import PIL
from PIL import Image

# %%
# Custom loss for the model (based on SSIM)
def custom_ssim(y_actual, y_predicted):
    y_actual = (1+y_actual)/2
    y_predicted = (1+y_predicted)/2
    return 1 - tf.image.ssim(y_actual, y_predicted, max_val=1)

# %%
# Training parameters
num_train1 = 20 # number of images used in training degraded by sigma = 1 (gaussian blur)
num_train3 = 20 # number of images used in training degraded by sigma = 3 (gaussian blur)

# %%
# Loading data for training
soma1 = num_train1 + num_train3

blurred_train_aux = np.zeros((soma1, 256, 256, 1)) # array with degraded images for training 
original_train_aux = np.zeros((soma1, 256, 256, 1)) # array with non-degraded images for training

# Images degraded by sigma = 1 and dimension = (7, 7) (gaussian blur)
for i in range (1, num_train1+1):
    blurred_train_aux[i-1, :, :, 0] = np.load('dataset_gray/sigma1(7, 7)/arrays/degradada' + str(i) + '.npy')
    original_train_aux[i-1, :, :, 0] = np.load('dataset_gray/original/arrays/original' + str(i) + '.npy')

# Images degraded by sigma = 3 and dimension = (7, 7) (gaussian blur)
for i in range (1, num_train3+1):
    blurred_train_aux[i+num_train1-1, :, :, 0] = np.load('dataset_gray/sigma3(7, 7)/arrays/degradada' + str(i) + '.npy')
    original_train_aux[i+num_train1-1, :, :, 0] = np.load('dataset_gray/original/arrays/original' + str(i) + '.npy')

# %%
# Normalizing data
blurred_train_aux = blurred_train_aux/(blurred_train_aux.max())
original_train_aux = original_train_aux/(original_train_aux.max())

# %%
# Range of data: -1 to 1
blurred_train = 2*blurred_train_aux - 1
original_train = 2*original_train_aux - 1

# %%
# Converting data to tensor for SSIM comparison (SSIM function from Tensorflow library)
blurred_train_tf = tf.convert_to_tensor(blurred_train_aux)
original_train_tf = tf.convert_to_tensor(original_train_aux)

# %%
plt.imshow(original_train_aux[0, :, :, 0], cmap='gray')

# %%
plt.imshow(blurred_train_aux[0, :, :, 0], cmap='gray')

# %%
# Loading data for testing
blurred_test_aux = np.zeros((2, 256, 256, 1)) # array with degraded images for testing
original_test_aux = np.zeros((2, 256, 256, 1)) # array with non-degraded images for testing

# Images degraded by sigma = 1 and dimension = (7, 7) (gaussian blur)
blurred_test_aux[0, :, :, 0] = np.load('dataset_gray/sigma1(7, 7)/arrays/degradada.npy')
original_test_aux[0, :, :, 0] = np.load('dataset_gray/original/arrays/original.npy')

# Images degraded by sigma = 3 and dimension = (7, 7) (gaussian blur)
blurred_test_aux[1, :, :, 0] = np.load('dataset_gray/sigma3(7, 7)/arrays/degradada.npy')
original_test_aux[1, :, :, 0] = np.load('dataset_gray/original/arrays/original.npy')

# %%
# Normalizing data
blurred_test_aux = blurred_test_aux/(blurred_test_aux.max())
original_test_aux = original_test_aux/(original_test_aux.max())

# %%
# Range of data: -1 to 1
blurred_test = 2*blurred_test_aux - 1
original_test = 2*original_test_aux - 1

# %%
# Converting data to tensor for SSIM comparison (SSIM function from Tensorflow library)
blurred_test_tf = tf.convert_to_tensor(blurred_test_aux)
original_test_tf = tf.convert_to_tensor(original_test_aux)

# %%
plt.imshow(original_test_aux[0, :, :, 0], cmap='gray')

# %%
plt.imshow(blurred_test_aux[0, :, :, 0], cmap='gray')

# %%
# Network model
def make_autoencoder(input_shape):
  
    X_input = Input(input_shape)

    X = Conv2D(1, (7, 7), padding="same")(X_input)
    X0 = Activation('tanh')(X)
    
    X = Conv2D(4, (7, 7), padding="same")(X0)
    X1 = Activation('tanh')(X)
    
    X = Conv2D(8, (7, 7), padding="same")(X1)
    X2 = Activation('tanh')(X)
    
    X = Conv2D(16, (7, 7), padding="same")(X2)
    X3 = Activation('tanh')(X)
    
    X = Conv2D(32, (7, 7), padding="same")(X3)
    X = Activation('tanh')(X)
 
    #latent space

    X = Conv2D(16, (7, 7), padding="same")(X)
    X = Activation('tanh')(X)
    X = Add()([X3, X])
    
    X = Conv2D(8, (7, 7), padding="same")(X)
    X = Activation('tanh')(X)
    X = Add()([X2, X])
    
    X = Conv2D(4, (7, 7), padding="same")(X)
    X = Activation('tanh')(X)
    X = Add()([X1, X])
    
    X = Conv2D(1, (7, 7), padding="same")(X)
    X = Activation('tanh')(X)
    X = Add()([X0, X])
    
    X = Conv2D(1, (7, 7), padding="same")(X)
    X = Activation('tanh')(X)
    

    model = Model(inputs=X_input, outputs=X)
    
    return model

# %%
mirrored_strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(mirrored_strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %%
opt = Adam(lr=1e-4)

# %%
# Training with 2 GPUs
with mirrored_strategy.scope():
    model = make_autoencoder(original_train.shape[1:])
    model.compile(optimizer=opt, loss=custom_ssim)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 1)  50          input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 1)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 4)  200         activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 4)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 8)  1576        activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 8)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 16) 6288        activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 256, 16) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 32) 25120       activation_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 256, 256, 32) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 256, 16) 25104       activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 256, 256, 16) 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256, 256, 16) 0           activation_3[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 8)  6280        add[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 256, 256, 8)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256, 256, 8)  0           activation_2[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 4)  1572        add_1[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 256, 256, 4)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 256, 256, 4)  0           activation_1[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 1)  197         add_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256, 256, 1)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 256, 256, 1)  0           activation[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 256, 256, 1)  50          add_3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 256, 256, 1)  0           conv2d_9[0][0]
# ==================================================================================================
# Total params: 66,437
# Trainable params: 66,437
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(x=blurred_train, y=original_train, epochs=20000, validation_data=[blurred_test, original_test])
# Out:
# Train on 40 samples, validate on 2 samples
# Epoch 1/20000
# INFO:tensorflow:batch_all_reduce: 20 all-reduces with algorithm = nccl, num_packs = 1, agg_small_grads_max_bytes = 0 and agg_small_grads_max_group = 10
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 20 all-reduces with algorithm = nccl, num_packs = 1, agg_small_grads_max_bytes = 0 and agg_small_grads_max_group = 10
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 32/40 [=======================>......] - ETA: 1s - loss: 0.8437INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 40/40 [==============================] - 7s 184ms/sample - loss: 0.8496 - val_loss: 0.7019
# Epoch 2/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.7915 - val_loss: 0.6113
# Epoch 3/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.7297 - val_loss: 0.5317
# Epoch 4/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.6724 - val_loss: 0.4705
# Epoch 5/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.6269 - val_loss: 0.4274
# Epoch 6/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.5941 - val_loss: 0.3972
# Epoch 7/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.5669 - val_loss: 0.3756
# Epoch 8/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.5427 - val_loss: 0.3604
# Epoch 9/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.5228 - val_loss: 0.3513
# Epoch 10/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.5094 - val_loss: 0.3479
# Epoch 11/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.5022 - val_loss: 0.3452
# Epoch 12/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4979 - val_loss: 0.3389
# Epoch 13/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4932 - val_loss: 0.3300
# Epoch 14/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4872 - val_loss: 0.3206
# Epoch 15/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4808 - val_loss: 0.3124
# Epoch 16/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4746 - val_loss: 0.3056
# Epoch 17/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4686 - val_loss: 0.2998
# Epoch 18/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4627 - val_loss: 0.2951
# Epoch 19/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4574 - val_loss: 0.2912
# Epoch 20/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4527 - val_loss: 0.2872
# Epoch 21/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4483 - val_loss: 0.2829
# Epoch 22/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4441 - val_loss: 0.2787
# Epoch 23/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4403 - val_loss: 0.2741
# Epoch 24/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4363 - val_loss: 0.2693
# Epoch 25/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4326 - val_loss: 0.2651
# Epoch 26/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4289 - val_loss: 0.2616
# Epoch 27/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4254 - val_loss: 0.2587
# Epoch 28/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4220 - val_loss: 0.2561
# Epoch 29/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4189 - val_loss: 0.2533
# Epoch 30/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4158 - val_loss: 0.2500
# Epoch 31/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4128 - val_loss: 0.2464
# Epoch 32/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4100 - val_loss: 0.2432
# Epoch 33/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4072 - val_loss: 0.2407
# Epoch 34/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4045 - val_loss: 0.2385
# Epoch 35/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4019 - val_loss: 0.2360
# Epoch 36/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3995 - val_loss: 0.2332
# Epoch 37/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3973 - val_loss: 0.2308
# Epoch 38/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3949 - val_loss: 0.2295
# Epoch 39/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3926 - val_loss: 0.2283
# Epoch 40/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3906 - val_loss: 0.2258
# Epoch 41/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3884 - val_loss: 0.2231
# Epoch 42/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3864 - val_loss: 0.2210
# Epoch 43/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3844 - val_loss: 0.2197
# Epoch 44/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3825 - val_loss: 0.2185
# Epoch 45/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3807 - val_loss: 0.2162
# Epoch 46/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3788 - val_loss: 0.2141
# Epoch 47/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3771 - val_loss: 0.2127
# Epoch 48/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3754 - val_loss: 0.2116
# Epoch 49/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3737 - val_loss: 0.2097
# Epoch 50/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3721 - val_loss: 0.2079
# Epoch 51/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3705 - val_loss: 0.2069
# Epoch 52/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3689 - val_loss: 0.2061
# Epoch 53/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3674 - val_loss: 0.2042
# Epoch 54/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3660 - val_loss: 0.2023
# Epoch 55/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3645 - val_loss: 0.2011
# Epoch 56/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3630 - val_loss: 0.2000
# Epoch 57/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3616 - val_loss: 0.1987
# Epoch 58/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3602 - val_loss: 0.1976
# Epoch 59/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3587 - val_loss: 0.1971
# Epoch 60/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3574 - val_loss: 0.1961
# Epoch 61/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3561 - val_loss: 0.1940
# Epoch 62/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3547 - val_loss: 0.1924
# Epoch 63/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3536 - val_loss: 0.1915
# Epoch 64/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3521 - val_loss: 0.1913
# Epoch 65/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3510 - val_loss: 0.1906
# Epoch 66/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3497 - val_loss: 0.1887
# Epoch 67/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3485 - val_loss: 0.1872
# Epoch 68/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3471 - val_loss: 0.1869
# Epoch 69/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3461 - val_loss: 0.1858
# Epoch 70/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3449 - val_loss: 0.1839
# Epoch 71/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3436 - val_loss: 0.1830
# Epoch 72/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3425 - val_loss: 0.1828
# Epoch 73/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3415 - val_loss: 0.1820
# Epoch 74/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3405 - val_loss: 0.1804
# Epoch 75/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3392 - val_loss: 0.1790
# Epoch 76/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3382 - val_loss: 0.1780
# Epoch 77/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3374 - val_loss: 0.1773
# Epoch 78/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3363 - val_loss: 0.1766
# Epoch 79/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3352 - val_loss: 0.1758
# Epoch 80/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3342 - val_loss: 0.1749
# Epoch 81/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3333 - val_loss: 0.1741
# Epoch 82/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3325 - val_loss: 0.1734
# Epoch 83/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3315 - val_loss: 0.1721
# Epoch 84/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3305 - val_loss: 0.1712
# Epoch 85/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3297 - val_loss: 0.1706
# Epoch 86/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3289 - val_loss: 0.1699
# Epoch 87/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3279 - val_loss: 0.1694
# Epoch 88/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3272 - val_loss: 0.1689
# Epoch 89/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3263 - val_loss: 0.1685
# Epoch 90/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3255 - val_loss: 0.1678
# Epoch 91/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3249 - val_loss: 0.1663
# Epoch 92/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3239 - val_loss: 0.1655
# Epoch 93/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3233 - val_loss: 0.1651
# Epoch 94/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3224 - val_loss: 0.1647
# Epoch 95/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3216 - val_loss: 0.1636
# Epoch 96/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3212 - val_loss: 0.1630
# Epoch 97/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3204 - val_loss: 0.1634
# Epoch 98/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3199 - val_loss: 0.1629
# Epoch 99/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3193 - val_loss: 0.1605
# Epoch 100/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3186 - val_loss: 0.1597
# Epoch 101/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3177 - val_loss: 0.1602
# Epoch 102/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3169 - val_loss: 0.1584
# Epoch 103/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3163 - val_loss: 0.1578
# Epoch 104/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3157 - val_loss: 0.1582
# Epoch 105/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3150 - val_loss: 0.1574
# Epoch 106/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3142 - val_loss: 0.1570
# Epoch 107/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3139 - val_loss: 0.1566
# Epoch 108/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3129 - val_loss: 0.1565
# Epoch 109/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3122 - val_loss: 0.1553
# Epoch 110/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3118 - val_loss: 0.1547
# Epoch 111/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3109 - val_loss: 0.1558
# Epoch 112/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3108 - val_loss: 0.1542
# Epoch 113/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3100 - val_loss: 0.1541
# Epoch 114/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3097 - val_loss: 0.1546
# Epoch 115/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3090 - val_loss: 0.1536
# Epoch 116/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3082 - val_loss: 0.1524
# Epoch 117/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3080 - val_loss: 0.1516
# Epoch 118/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3070 - val_loss: 0.1525
# Epoch 119/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3067 - val_loss: 0.1511
# Epoch 120/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3059 - val_loss: 0.1508
# Epoch 121/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3057 - val_loss: 0.1502
# Epoch 122/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3048 - val_loss: 0.1501
# Epoch 123/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3044 - val_loss: 0.1488
# Epoch 124/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3038 - val_loss: 0.1482
# Epoch 125/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3034 - val_loss: 0.1474
# Epoch 126/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3026 - val_loss: 0.1479
# Epoch 127/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3033 - val_loss: 0.1469
# Epoch 128/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3021 - val_loss: 0.1473
# Epoch 129/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3016 - val_loss: 0.1466
# Epoch 130/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3021 - val_loss: 0.1457
# Epoch 131/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3008 - val_loss: 0.1489
# Epoch 132/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3018 - val_loss: 0.1448
# Epoch 133/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2999 - val_loss: 0.1468
# Epoch 134/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.3009 - val_loss: 0.1457
# Epoch 135/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2990 - val_loss: 0.1457
# Epoch 136/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2982 - val_loss: 0.1451
# Epoch 137/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2987 - val_loss: 0.1438
# Epoch 138/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2974 - val_loss: 0.1450
# Epoch 139/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2972 - val_loss: 0.1428
# Epoch 140/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2961 - val_loss: 0.1434
# Epoch 141/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2966 - val_loss: 0.1425
# Epoch 142/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2955 - val_loss: 0.1424
# Epoch 143/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2949 - val_loss: 0.1419
# Epoch 144/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2950 - val_loss: 0.1409
# Epoch 145/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2941 - val_loss: 0.1408
# Epoch 146/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2938 - val_loss: 0.1407
# Epoch 147/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2935 - val_loss: 0.1396
# Epoch 148/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2927 - val_loss: 0.1402
# Epoch 149/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2927 - val_loss: 0.1400
# Epoch 150/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2921 - val_loss: 0.1407
# Epoch 151/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2918 - val_loss: 0.1394
# Epoch 152/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2914 - val_loss: 0.1398
# Epoch 153/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2911 - val_loss: 0.1396
# Epoch 154/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2905 - val_loss: 0.1386
# Epoch 155/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2899 - val_loss: 0.1380
# Epoch 156/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2895 - val_loss: 0.1378
# Epoch 157/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2891 - val_loss: 0.1376
# Epoch 158/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2887 - val_loss: 0.1372
# Epoch 159/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2883 - val_loss: 0.1366
# Epoch 160/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2879 - val_loss: 0.1362
# Epoch 161/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2878 - val_loss: 0.1357
# Epoch 162/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2873 - val_loss: 0.1352
# Epoch 163/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2868 - val_loss: 0.1352
# Epoch 164/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2866 - val_loss: 0.1354
# Epoch 165/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2863 - val_loss: 0.1349
# Epoch 166/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2858 - val_loss: 0.1340
# Epoch 167/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2855 - val_loss: 0.1339
# Epoch 168/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2852 - val_loss: 0.1348
# Epoch 169/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2853 - val_loss: 0.1336
# Epoch 170/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2847 - val_loss: 0.1336
# Epoch 171/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2843 - val_loss: 0.1341
# Epoch 172/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2845 - val_loss: 0.1324
# Epoch 173/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2834 - val_loss: 0.1330
# Epoch 174/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2831 - val_loss: 0.1335
# Epoch 175/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2827 - val_loss: 0.1327
# Epoch 176/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2823 - val_loss: 0.1325
# Epoch 177/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2821 - val_loss: 0.1325
# Epoch 178/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2816 - val_loss: 0.1322
# Epoch 179/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2812 - val_loss: 0.1319
# Epoch 180/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2809 - val_loss: 0.1314
# Epoch 181/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2806 - val_loss: 0.1305
# Epoch 182/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2805 - val_loss: 0.1299
# Epoch 183/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2801 - val_loss: 0.1302
# Epoch 184/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2799 - val_loss: 0.1297
# Epoch 185/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2795 - val_loss: 0.1298
# Epoch 186/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2792 - val_loss: 0.1295
# Epoch 187/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2789 - val_loss: 0.1291
# Epoch 188/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2786 - val_loss: 0.1286
# Epoch 189/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2781 - val_loss: 0.1295
# Epoch 190/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2785 - val_loss: 0.1297
# Epoch 191/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2780 - val_loss: 0.1288
# Epoch 192/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2772 - val_loss: 0.1285
# Epoch 193/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2772 - val_loss: 0.1287
# Epoch 194/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2767 - val_loss: 0.1288
# Epoch 195/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2764 - val_loss: 0.1276
# Epoch 196/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2759 - val_loss: 0.1274
# Epoch 197/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2754 - val_loss: 0.1283
# Epoch 198/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2752 - val_loss: 0.1274
# Epoch 199/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2749 - val_loss: 0.1269
# Epoch 200/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2748 - val_loss: 0.1274
# Epoch 201/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2744 - val_loss: 0.1276
# Epoch 202/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2742 - val_loss: 0.1268
# Epoch 203/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2743 - val_loss: 0.1257
# Epoch 204/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2736 - val_loss: 0.1268
# Epoch 205/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2736 - val_loss: 0.1262
# Epoch 206/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2729 - val_loss: 0.1246
# Epoch 207/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2729 - val_loss: 0.1243
# Epoch 208/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2726 - val_loss: 0.1248
# Epoch 209/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2720 - val_loss: 0.1254
# Epoch 210/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2720 - val_loss: 0.1249
# Epoch 211/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2716 - val_loss: 0.1246
# Epoch 212/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2713 - val_loss: 0.1242
# Epoch 213/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2709 - val_loss: 0.1240
# Epoch 214/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2706 - val_loss: 0.1245
# Epoch 215/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2704 - val_loss: 0.1257
# Epoch 216/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2704 - val_loss: 0.1255
# Epoch 217/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2698 - val_loss: 0.1253
# Epoch 218/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2702 - val_loss: 0.1240
# Epoch 219/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2694 - val_loss: 0.1248
# Epoch 220/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2696 - val_loss: 0.1247
# Epoch 221/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2691 - val_loss: 0.1237
# Epoch 222/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2691 - val_loss: 0.1229
# Epoch 223/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2680 - val_loss: 0.1243
# Epoch 224/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2689 - val_loss: 0.1223
# Epoch 225/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2681 - val_loss: 0.1229
# Epoch 226/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2682 - val_loss: 0.1249
# Epoch 227/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2682 - val_loss: 0.1222
# Epoch 228/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2672 - val_loss: 0.1220
# Epoch 229/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2672 - val_loss: 0.1224
# Epoch 230/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2669 - val_loss: 0.1214
# Epoch 231/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2662 - val_loss: 0.1211
# Epoch 232/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2665 - val_loss: 0.1223
# Epoch 233/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2661 - val_loss: 0.1226
# Epoch 234/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2656 - val_loss: 0.1210
# Epoch 235/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2653 - val_loss: 0.1205
# Epoch 236/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2651 - val_loss: 0.1217
# Epoch 237/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2649 - val_loss: 0.1220
# Epoch 238/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2646 - val_loss: 0.1214
# Epoch 239/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2646 - val_loss: 0.1206
# Epoch 240/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2643 - val_loss: 0.1205
# Epoch 241/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2640 - val_loss: 0.1200
# Epoch 242/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2638 - val_loss: 0.1199
# Epoch 243/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2640 - val_loss: 0.1205
# Epoch 244/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2637 - val_loss: 0.1206
# Epoch 245/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.2634 - val_loss: 0.1183
# Epoch 246/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2631 - val_loss: 0.1185
# Epoch 247/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2626 - val_loss: 0.1196
# Epoch 248/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2624 - val_loss: 0.1188
# Epoch 249/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2624 - val_loss: 0.1190
# Epoch 250/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2618 - val_loss: 0.1210
# Epoch 251/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2622 - val_loss: 0.1193
# Epoch 252/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2614 - val_loss: 0.1183
# Epoch 253/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2611 - val_loss: 0.1183
# Epoch 254/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2608 - val_loss: 0.1185
# Epoch 255/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2605 - val_loss: 0.1181
# Epoch 256/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2603 - val_loss: 0.1177
# Epoch 257/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2599 - val_loss: 0.1177
# Epoch 258/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2601 - val_loss: 0.1170
# Epoch 259/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2596 - val_loss: 0.1167
# Epoch 260/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2594 - val_loss: 0.1170
# Epoch 261/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2594 - val_loss: 0.1171
# Epoch 262/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2590 - val_loss: 0.1173
# Epoch 263/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2588 - val_loss: 0.1171
# Epoch 264/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2585 - val_loss: 0.1169
# Epoch 265/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2583 - val_loss: 0.1168
# Epoch 266/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2581 - val_loss: 0.1169
# Epoch 267/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2580 - val_loss: 0.1171
# Epoch 268/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2577 - val_loss: 0.1164
# Epoch 269/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2575 - val_loss: 0.1162
# Epoch 270/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2574 - val_loss: 0.1164
# Epoch 271/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2574 - val_loss: 0.1160
# Epoch 272/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2571 - val_loss: 0.1158
# Epoch 273/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2568 - val_loss: 0.1158
# Epoch 274/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2569 - val_loss: 0.1151
# Epoch 275/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2562 - val_loss: 0.1156
# Epoch 276/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2564 - val_loss: 0.1154
# Epoch 277/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2558 - val_loss: 0.1154
# Epoch 278/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2558 - val_loss: 0.1154
# Epoch 279/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2557 - val_loss: 0.1153
# Epoch 280/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2557 - val_loss: 0.1148
# Epoch 281/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2553 - val_loss: 0.1143
# Epoch 282/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2552 - val_loss: 0.1150
# Epoch 283/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2551 - val_loss: 0.1156
# Epoch 284/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2551 - val_loss: 0.1146
# Epoch 285/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2546 - val_loss: 0.1138
# Epoch 286/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2546 - val_loss: 0.1133
# Epoch 287/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2545 - val_loss: 0.1138
# Epoch 288/20000
# 40/40 [==============================] - 0s 6ms/sample - loss: 0.2542 - val_loss: 0.1136
# Epoch 289/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2539 - val_loss: 0.1136
# Epoch 290/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2538 - val_loss: 0.1129
# Epoch 291/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2534 - val_loss: 0.1128
# Epoch 292/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2531 - val_loss: 0.1141
# Epoch 293/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2537 - val_loss: 0.1141
# Epoch 294/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2530 - val_loss: 0.1145
# Epoch 295/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2536 - val_loss: 0.1139
# Epoch 296/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2530 - val_loss: 0.1144
# Epoch 297/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2526 - val_loss: 0.1140
# Epoch 298/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2524 - val_loss: 0.1145
# Epoch 299/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2526 - val_loss: 0.1140
# Epoch 300/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2517 - val_loss: 0.1134
# Epoch 301/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2517 - val_loss: 0.1129
# Epoch 302/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2522 - val_loss: 0.1125
# Epoch 303/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2517 - val_loss: 0.1134
# Epoch 304/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2516 - val_loss: 0.1131
# Epoch 305/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2515 - val_loss: 0.1119
# Epoch 306/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2515 - val_loss: 0.1118
# Epoch 307/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2504 - val_loss: 0.1147
# Epoch 308/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2518 - val_loss: 0.1143
# Epoch 309/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2515 - val_loss: 0.1139
# Epoch 310/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2514 - val_loss: 0.1140
# Epoch 311/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2510 - val_loss: 0.1123
# Epoch 312/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2504 - val_loss: 0.1122
# Epoch 313/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2499 - val_loss: 0.1131
# Epoch 314/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2503 - val_loss: 0.1130
# Epoch 315/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2493 - val_loss: 0.1133
# Epoch 316/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2503 - val_loss: 0.1108
# Epoch 317/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2496 - val_loss: 0.1122
# Epoch 318/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2495 - val_loss: 0.1130
# Epoch 319/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2499 - val_loss: 0.1120
# Epoch 320/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2490 - val_loss: 0.1129
# Epoch 321/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2492 - val_loss: 0.1110
# Epoch 322/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2481 - val_loss: 0.1110
# Epoch 323/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2490 - val_loss: 0.1098
# Epoch 324/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2477 - val_loss: 0.1131
# Epoch 325/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2488 - val_loss: 0.1115
# Epoch 326/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2478 - val_loss: 0.1116
# Epoch 327/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2486 - val_loss: 0.1105
# Epoch 328/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2477 - val_loss: 0.1123
# Epoch 329/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2478 - val_loss: 0.1103
# Epoch 330/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2473 - val_loss: 0.1093
# Epoch 331/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2471 - val_loss: 0.1104
# Epoch 332/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2467 - val_loss: 0.1116
# Epoch 333/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2469 - val_loss: 0.1103
# Epoch 334/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2467 - val_loss: 0.1097
# Epoch 335/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2464 - val_loss: 0.1110
# Epoch 336/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2464 - val_loss: 0.1097
# Epoch 337/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2459 - val_loss: 0.1093
# Epoch 338/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2458 - val_loss: 0.1106
# Epoch 339/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2458 - val_loss: 0.1110
# Epoch 340/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2457 - val_loss: 0.1100
# Epoch 341/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2453 - val_loss: 0.1098
# Epoch 342/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2455 - val_loss: 0.1094
# Epoch 343/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2449 - val_loss: 0.1102
# Epoch 344/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2452 - val_loss: 0.1097
# Epoch 345/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2446 - val_loss: 0.1093
# Epoch 346/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2448 - val_loss: 0.1089
# Epoch 347/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2445 - val_loss: 0.1087
# Epoch 348/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2442 - val_loss: 0.1081
# Epoch 349/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2442 - val_loss: 0.1077
# Epoch 350/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2439 - val_loss: 0.1086
# Epoch 351/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2439 - val_loss: 0.1088
# Epoch 352/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2438 - val_loss: 0.1080
# Epoch 353/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2435 - val_loss: 0.1074
# Epoch 354/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2434 - val_loss: 0.1081
# Epoch 355/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2435 - val_loss: 0.1085
# Epoch 356/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2433 - val_loss: 0.1093
# Epoch 357/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2434 - val_loss: 0.1083
# Epoch 358/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2430 - val_loss: 0.1074
# Epoch 359/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2427 - val_loss: 0.1081
# Epoch 360/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2431 - val_loss: 0.1078
# Epoch 361/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2430 - val_loss: 0.1074
# Epoch 362/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2433 - val_loss: 0.1072
# Epoch 363/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2429 - val_loss: 0.1079
# Epoch 364/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2425 - val_loss: 0.1066
# Epoch 365/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2423 - val_loss: 0.1055
# Epoch 366/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2423 - val_loss: 0.1061
# Epoch 367/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2418 - val_loss: 0.1079
# Epoch 368/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2420 - val_loss: 0.1079
# Epoch 369/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2419 - val_loss: 0.1076
# Epoch 370/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2416 - val_loss: 0.1081
# Epoch 371/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2417 - val_loss: 0.1078
# Epoch 372/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2414 - val_loss: 0.1076
# Epoch 373/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2414 - val_loss: 0.1078
# Epoch 374/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2414 - val_loss: 0.1076
# Epoch 375/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2408 - val_loss: 0.1066
# Epoch 376/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2411 - val_loss: 0.1057
# Epoch 377/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2407 - val_loss: 0.1061
# Epoch 378/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2404 - val_loss: 0.1070
# Epoch 379/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2405 - val_loss: 0.1065
# Epoch 380/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2403 - val_loss: 0.1060
# Epoch 381/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2400 - val_loss: 0.1068
# Epoch 382/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2402 - val_loss: 0.1058
# Epoch 383/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2398 - val_loss: 0.1051
# Epoch 384/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2398 - val_loss: 0.1057
# Epoch 385/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2396 - val_loss: 0.1061
# Epoch 386/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2395 - val_loss: 0.1063
# Epoch 387/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2395 - val_loss: 0.1059
# Epoch 388/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2392 - val_loss: 0.1052
# Epoch 389/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2390 - val_loss: 0.1049
# Epoch 390/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2393 - val_loss: 0.1056
# Epoch 391/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2388 - val_loss: 0.1078
# Epoch 392/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2397 - val_loss: 0.1053
# Epoch 393/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2394 - val_loss: 0.1053
# Epoch 394/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2393 - val_loss: 0.1074
# Epoch 395/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2396 - val_loss: 0.1061
# Epoch 396/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2385 - val_loss: 0.1057
# Epoch 397/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2390 - val_loss: 0.1055
# Epoch 398/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2380 - val_loss: 0.1075
# Epoch 399/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2390 - val_loss: 0.1052
# Epoch 400/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2384 - val_loss: 0.1044
# Epoch 401/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2387 - val_loss: 0.1049
# Epoch 402/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2380 - val_loss: 0.1058
# Epoch 403/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2376 - val_loss: 0.1047
# Epoch 404/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2379 - val_loss: 0.1052
# Epoch 405/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2379 - val_loss: 0.1071
# Epoch 406/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2381 - val_loss: 0.1053
# Epoch 407/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2378 - val_loss: 0.1040
# Epoch 408/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2373 - val_loss: 0.1063
# Epoch 409/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2378 - val_loss: 0.1061
# Epoch 410/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2372 - val_loss: 0.1054
# Epoch 411/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2372 - val_loss: 0.1066
# Epoch 412/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2373 - val_loss: 0.1078
# Epoch 413/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2373 - val_loss: 0.1062
# Epoch 414/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2369 - val_loss: 0.1052
# Epoch 415/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2371 - val_loss: 0.1048
# Epoch 416/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2364 - val_loss: 0.1061
# Epoch 417/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2372 - val_loss: 0.1033
# Epoch 418/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2367 - val_loss: 0.1034
# Epoch 419/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2373 - val_loss: 0.1035
# Epoch 420/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2361 - val_loss: 0.1054
# Epoch 421/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2371 - val_loss: 0.1039
# Epoch 422/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2360 - val_loss: 0.1043
# Epoch 423/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2363 - val_loss: 0.1043
# Epoch 424/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2357 - val_loss: 0.1058
# Epoch 425/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2364 - val_loss: 0.1045
# Epoch 426/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2354 - val_loss: 0.1034
# Epoch 427/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2357 - val_loss: 0.1030
# Epoch 428/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2353 - val_loss: 0.1042
# Epoch 429/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2355 - val_loss: 0.1042
# Epoch 430/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2352 - val_loss: 0.1043
# Epoch 431/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2352 - val_loss: 0.1040
# Epoch 432/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2349 - val_loss: 0.1037
# Epoch 433/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2351 - val_loss: 0.1040
# Epoch 434/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2349 - val_loss: 0.1053
# Epoch 435/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2348 - val_loss: 0.1051
# Epoch 436/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2348 - val_loss: 0.1044
# Epoch 437/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2350 - val_loss: 0.1051
# Epoch 438/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2348 - val_loss: 0.1056
# Epoch 439/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2347 - val_loss: 0.1037
# Epoch 440/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2345 - val_loss: 0.1032
# Epoch 441/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2348 - val_loss: 0.1029
# Epoch 442/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2342 - val_loss: 0.1033
# Epoch 443/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2342 - val_loss: 0.1028
# Epoch 444/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2339 - val_loss: 0.1037
# Epoch 445/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2343 - val_loss: 0.1044
# Epoch 446/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.2338 - val_loss: 0.1047
# Epoch 447/20000
# ...
# Epoch 19852/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0448
# Epoch 19853/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0983 - val_loss: 0.0449
# Epoch 19854/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0447
# Epoch 19855/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0444
# Epoch 19856/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0444
# Epoch 19857/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0444
# Epoch 19858/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0446
# Epoch 19859/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0446
# Epoch 19860/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0445
# Epoch 19861/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0456
# Epoch 19862/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0986 - val_loss: 0.0460
# Epoch 19863/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0987 - val_loss: 0.0452
# Epoch 19864/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.0986 - val_loss: 0.0448
# Epoch 19865/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0985 - val_loss: 0.0447
# Epoch 19866/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0449
# Epoch 19867/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0983 - val_loss: 0.0453
# Epoch 19868/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0985 - val_loss: 0.0445
# Epoch 19869/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0983 - val_loss: 0.0444
# Epoch 19870/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0984 - val_loss: 0.0453
# Epoch 19871/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0983 - val_loss: 0.0449
# Epoch 19872/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0450
# Epoch 19873/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0984 - val_loss: 0.0449
# Epoch 19874/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0984 - val_loss: 0.0445
# Epoch 19875/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0984 - val_loss: 0.0447
# Epoch 19876/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0983 - val_loss: 0.0450
# Epoch 19877/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0447
# Epoch 19878/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0452
# Epoch 19879/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0455
# Epoch 19880/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0446
# Epoch 19881/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0446
# Epoch 19882/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0448
# Epoch 19883/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0451
# Epoch 19884/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0453
# Epoch 19885/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0445
# Epoch 19886/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0447
# Epoch 19887/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.0979 - val_loss: 0.0453
# Epoch 19888/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0448
# Epoch 19889/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0446
# Epoch 19890/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0449
# Epoch 19891/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0444
# Epoch 19892/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0445
# Epoch 19893/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0447
# Epoch 19894/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0446
# Epoch 19895/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0448
# Epoch 19896/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0447
# Epoch 19897/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0443
# Epoch 19898/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0443
# Epoch 19899/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0450
# Epoch 19900/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0444
# Epoch 19901/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0444
# Epoch 19902/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0451
# Epoch 19903/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0448
# Epoch 19904/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0445
# Epoch 19905/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0446
# Epoch 19906/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0448
# Epoch 19907/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0983 - val_loss: 0.0447
# Epoch 19908/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0983 - val_loss: 0.0447
# Epoch 19909/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0454
# Epoch 19910/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0447
# Epoch 19911/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0448
# Epoch 19912/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0454
# Epoch 19913/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0444
# Epoch 19914/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0444
# Epoch 19915/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0448
# Epoch 19916/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0446
# Epoch 19917/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.0978 - val_loss: 0.0446
# Epoch 19918/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0445
# Epoch 19919/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0447
# Epoch 19920/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0449
# Epoch 19921/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0446
# Epoch 19922/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0448
# Epoch 19923/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.0978 - val_loss: 0.0451
# Epoch 19924/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0444
# Epoch 19925/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0443
# Epoch 19926/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0447
# Epoch 19927/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0443
# Epoch 19928/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0441
# Epoch 19929/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0446
# Epoch 19930/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0977 - val_loss: 0.0446
# Epoch 19931/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0444
# Epoch 19932/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0448
# Epoch 19933/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0446
# Epoch 19934/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0976 - val_loss: 0.0445
# Epoch 19935/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0445
# Epoch 19936/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0447
# Epoch 19937/20000
# 40/40 [==============================] - 0s 9ms/sample - loss: 0.0980 - val_loss: 0.0449
# Epoch 19938/20000
# 40/40 [==============================] - 0s 9ms/sample - loss: 0.0982 - val_loss: 0.0449
# Epoch 19939/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0444
# Epoch 19940/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0448
# Epoch 19941/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0452
# Epoch 19942/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0445
# Epoch 19943/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0442
# Epoch 19944/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0449
# Epoch 19945/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0451
# Epoch 19946/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0449
# Epoch 19947/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0449
# Epoch 19948/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0984 - val_loss: 0.0448
# Epoch 19949/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0985 - val_loss: 0.0463
# Epoch 19950/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.1000 - val_loss: 0.0450
# Epoch 19951/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.1002 - val_loss: 0.0450
# Epoch 19952/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0988 - val_loss: 0.0455
# Epoch 19953/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0985 - val_loss: 0.0453
# Epoch 19954/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0996 - val_loss: 0.0455
# Epoch 19955/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.1001 - val_loss: 0.0454
# Epoch 19956/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0998 - val_loss: 0.0469
# Epoch 19957/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0997 - val_loss: 0.0456
# Epoch 19958/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0988 - val_loss: 0.0456
# Epoch 19959/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0989 - val_loss: 0.0454
# Epoch 19960/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0986 - val_loss: 0.0457
# Epoch 19961/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0985 - val_loss: 0.0458
# Epoch 19962/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0983 - val_loss: 0.0446
# Epoch 19963/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0983 - val_loss: 0.0453
# Epoch 19964/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0985 - val_loss: 0.0453
# Epoch 19965/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0449
# Epoch 19966/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0446
# Epoch 19967/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0454
# Epoch 19968/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.0991 - val_loss: 0.0454
# Epoch 19969/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0991 - val_loss: 0.0449
# Epoch 19970/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0453
# Epoch 19971/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0984 - val_loss: 0.0447
# Epoch 19972/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0454
# Epoch 19973/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0986 - val_loss: 0.0455
# Epoch 19974/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0445
# Epoch 19975/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0448
# Epoch 19976/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0455
# Epoch 19977/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0983 - val_loss: 0.0448
# Epoch 19978/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0444
# Epoch 19979/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0446
# Epoch 19980/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0452
# Epoch 19981/20000
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.0979 - val_loss: 0.0448
# Epoch 19982/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0442
# Epoch 19983/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0446
# Epoch 19984/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0448
# Epoch 19985/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0981 - val_loss: 0.0447
# Epoch 19986/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0985 - val_loss: 0.0446
# Epoch 19987/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0450
# Epoch 19988/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0444
# Epoch 19989/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0442
# Epoch 19990/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0978 - val_loss: 0.0447
# Epoch 19991/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0977 - val_loss: 0.0447
# Epoch 19992/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0452
# Epoch 19993/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0983 - val_loss: 0.0447
# Epoch 19994/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0980 - val_loss: 0.0446
# Epoch 19995/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0446
# Epoch 19996/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0984 - val_loss: 0.0451
# Epoch 19997/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0444
# Epoch 19998/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0977 - val_loss: 0.0443
# Epoch 19999/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0979 - val_loss: 0.0447
# Epoch 20000/20000
# 40/40 [==============================] - 0s 8ms/sample - loss: 0.0982 - val_loss: 0.0456

# %%
# Plotting loss
plt.plot(10*np.log10(history.history['loss']))
plt.xlim(0, 20000)
plt.grid(color='black', linestyle='dotted')
plt.ylabel('1 - SSIM (dB)')
plt.xlabel('Época')
plt.savefig('saved/residual_ssim_sigmas13/error.eps', format='eps')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
# Saving model
model.save('saved/residual_ssim_sigmas13/model.h5')

# %% [markdown]
# **Results for image from test dataset degraded by sigma = 1**

# %%
blurred_test1_aux = np.zeros((2, 256, 256, 1))
original_test1_aux = np.zeros((2, 256, 256, 1))


blurred_test1_aux[0, :, :, 0] = np.load('dataset_gray/sigma1(7, 7)/arrays/degradada.npy')
original_test1_aux[0, :, :, 0] = np.load('dataset_gray/original/arrays/original.npy')

# %%
blurred_test1_aux = blurred_test1_aux/(blurred_test1_aux.max())
original_test1_aux = original_test1_aux/(original_test1_aux.max())

# %%
blurred_test1 = (2*blurred_test1_aux)-1
original_test1 = (2*original_test1_aux)-1

# %%
blurred_test1_tf = tf.convert_to_tensor(blurred_test1_aux)
original_test1_tf = tf.convert_to_tensor(original_test1_aux)

# %%
test_prediction1 = (1+model.predict(blurred_test1))/2
test_prediction1_tf = tf.convert_to_tensor(test_prediction1, np.float64)

# %%
plt.imshow(blurred_test1_aux[0 , :, :, 0], cmap='gray')

# %%
plt.imshow(original_test1_aux[0, :, :, 0], cmap='gray')

# %%
plt.imshow(test_prediction1[0, :, :, 0], cmap='gray')

# %%
# SSIM between original and degraded images
tf.image.ssim(original_test1_tf[0, :, :, :], blurred_test1_tf[0, :, :, :], max_val=1).numpy()
# Out:
# 0.9604327

# %%
# SSIM between original and restored images
tf.image.ssim(original_test1_tf[0, :, :, :], test_prediction1_tf[0, :, :, :], max_val=1).numpy()
# Out:
# 0.968274

# %% [markdown]
# **Results for image from test dataset degraded by sigma = 2**

# %%
blurred_test2_aux = np.zeros((2, 256, 256, 1))
original_test2_aux = np.zeros((2, 256, 256, 1))


blurred_test2_aux[0, :, :, 0] = np.load('dataset_gray/sigma2(7, 7)/arrays/degradada.npy')
original_test2_aux[0, :, :, 0] = np.load('dataset_gray/original/arrays/original.npy')

# %%
blurred_test2_aux = blurred_test2_aux/(blurred_test2_aux.max())
original_test2_aux = original_test2_aux/(original_test2_aux.max())

# %%
blurred_test2 = (2*blurred_test2_aux)-1
original_test2 = (2*original_test2_aux)-1

# %%
blurred_test2_tf = tf.convert_to_tensor(blurred_test2_aux)
original_test2_tf = tf.convert_to_tensor(original_test2_aux)

# %%
test_prediction2 = (1+model.predict(blurred_test2))/2
test_prediction2_tf = tf.convert_to_tensor(test_prediction2, np.float64)

# %%
plt.imshow(blurred_test2_aux[0 , :, :, 0], cmap='gray')

# %%
plt.imshow(original_test2_aux[0, :, :, 0], cmap='gray')

# %%
plt.imshow(test_prediction2[0, :, :, 0], cmap='gray')

# %%
# SSIM between original and degraded images
tf.image.ssim(original_test2_tf[0, :, :, :], blurred_test2_tf[0, :, :, :], max_val=1).numpy()
# Out:
# 0.8894724

# %%
# SSIM between original and restored images
tf.image.ssim(original_test2_tf[0, :, :, :], test_prediction2_tf[0, :, :, :], max_val=1).numpy()
# Out:
# 0.9267654

# %% [markdown]
# **Results for image from test dataset degraded by sigma = 3**

# %%
blurred_test3_aux = np.zeros((2, 256, 256, 1))
original_test3_aux = np.zeros((2, 256, 256, 1))


blurred_test3_aux[0, :, :, 0] = np.load('dataset_gray/sigma3(7, 7)/arrays/degradada.npy')
original_test3_aux[0, :, :, 0] = np.load('dataset_gray/original/arrays/original.npy')

# %%
blurred_test3_aux = blurred_test3_aux/(blurred_test3_aux.max())
original_test3_aux = original_test3_aux/(original_test3_aux.max())

# %%
blurred_test3 = (2*blurred_test3_aux)-1
original_test3 = (2*original_test3_aux)-1

# %%
blurred_test3_tf = tf.convert_to_tensor(blurred_test3_aux)
original_test3_tf = tf.convert_to_tensor(original_test3_aux)

# %%
test_prediction3 = (1+model.predict(blurred_test3))/2
test_prediction3_tf = tf.convert_to_tensor(test_prediction3, np.float64)

# %%
plt.imshow(blurred_test3_aux[0 , :, :, 0], cmap='gray')

# %%
plt.imshow(original_test3_aux[0, :, :, 0], cmap='gray')

# %%
plt.imshow(test_prediction3[0, :, :, 0], cmap='gray')

# %%
# SSIM between original and degraded images
tf.image.ssim(original_test3_tf[0, :, :, :], blurred_test3_tf[0, :, :, :], max_val=1).numpy()
# Out:
# 0.8623652

# %%
# SSIM between original and restored images
tf.image.ssim(original_test3_tf[0, :, :, :], test_prediction3_tf[0, :, :, :], max_val=1).numpy()
# Out:
# 0.939165
