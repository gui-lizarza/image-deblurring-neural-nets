# %%
import tensorflow as tf

# %%
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:1 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce RTX 2080, pci bus id: 0000:01:00.0, compute capability: 7.5
# /job:localhost/replica:0/task:0/device:GPU:1 -> device: 1, name: GeForce RTX 2080, pci bus id: 0000:02:00.0, compute capability: 7.5

# %%
tf.test.is_gpu_available()
# Out:
# True

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import scipy.ndimage

# %%
import PIL
from PIL import Image

# %%
# Problem parameters
num_img = 20 
max_color = 7 
janela = 7 
num_data = 250*250*num_img

# %%
# Preparing training data
data2 = np.zeros((num_data, janela, janela, 1))
labels2 = np.zeros((num_data, 1))
contador = 0

# Images degraded by sigma = 2 and dimension = (7, 7) (gaussian blur)
for i in range (1, num_img + 1):
    degradada = np.load('dataset_gray/sigma2(7, 7)/arrays/degradada' + str(i) + '.npy')
    original = np.load('dataset_gray/original/8/arrays/original' + str(i) + '.npy')
    
    for pixel_i in range(int((janela-1)/2), original.shape[0] - int((janela-1)/2)):
        for pixel_j in range(int((janela-1)/2), original.shape[0] - int((janela-1)/2)):
            if len(degradada.shape) == 2:
                crop = degradada[pixel_i - int((janela-1)/2):pixel_i + int((janela-1)/2) + 1,
                                 pixel_j - int((janela-1)/2):pixel_j + int((janela-1)/2) + 1]
                label = original[pixel_i, pixel_j]
            
            data2[contador, :, :, 0] = np.asmatrix(crop)
            labels2[contador, :] = np.asmatrix(label)
            contador = contador + 1

# %%
# Preparing test data
# Images degraded by sigma = 2 and dimension = (7, 7) (gaussian blur)
original = np.load('dataset_gray/original/8/arrays/original.npy')
degradada = np.load('dataset_gray/sigma2(7, 7)/arrays/degradada.npy')
test_data2 = np.zeros((250*250, 7, 7, 1))
test_labels2 = np.zeros((250*250, 1))
contador = 0
for pixel_i in range(int((janela-1)/2), original.shape[0] - int((janela-1)/2)):
    for pixel_j in range(int((janela-1)/2), original.shape[0] - int((janela-1)/2)):
        if len(degradada.shape) == 2:
            crop = degradada[pixel_i - int((janela-1)/2):pixel_i + int((janela-1)/2) + 1,
                             pixel_j - int((janela-1)/2):pixel_j + int((janela-1)/2) + 1]
            label = original[pixel_i, pixel_j]

        test_data2[contador, :, :, 0] = np.asmatrix(crop)
        test_labels2[contador, :] = np.asmatrix(label)
        contador = contador + 1

# %%
# Creating model
import tensorflow.keras 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Conv2D, Dense, Activation
from tensorflow.keras import optimizers

labels = np.rint(labels2)
t_labels = np.rint(test_labels2)
train_labels = tensorflow.keras.utils.to_categorical(labels2, num_classes=max_color + 1)
train_data = data2
test_labels = tensorflow.keras.utils.to_categorical(test_labels2, num_classes=max_color + 1)
test_data = test_data2

model = Sequential()

model.add(Conv2D(8, (3, 3), input_shape=(7, 7, 1)))
model.add(Activation('relu'))
model.add(Conv2D(16, (3, 3)))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(8))
model.add(Activation('softmax'))

opt = optimizers.Adam(lr=0.001,
                      beta_1=0.9,
                      beta_2=0.999,
                      epsilon=None,
                      decay=0.0,
                      amsgrad=False)

model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['categorical_accuracy'])

model.summary()

history = model.fit(train_data, train_labels, epochs=100, batch_size=512)

score = model.evaluate(x=test_data, y=test_labels, batch_size=1)

test_output = model.predict(test_data, batch_size=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 5, 5, 8)           80
# _________________________________________________________________
# activation (Activation)      (None, 5, 5, 8)           0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 3, 3, 16)          1168
# _________________________________________________________________
# activation_1 (Activation)    (None, 3, 3, 16)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 1, 32)          4640
# _________________________________________________________________
# activation_2 (Activation)    (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 264
# _________________________________________________________________
# activation_3 (Activation)    (None, 8)                 0
# =================================================================
# Total params: 6,152
# Trainable params: 6,152
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1250000 samples
# Epoch 1/100
# 1250000/1250000 [==============================] - 9s 7us/sample - loss: 0.7236 - categorical_accuracy: 0.7468
# Epoch 2/100
# 1250000/1250000 [==============================] - 8s 6us/sample - loss: 0.6306 - categorical_accuracy: 0.7727
# Epoch 3/100
# 1250000/1250000 [==============================] - 9s 7us/sample - loss: 0.6141 - categorical_accuracy: 0.7773
# Epoch 4/100
# 1250000/1250000 [==============================] - 9s 7us/sample - loss: 0.6007 - categorical_accuracy: 0.7814
# Epoch 5/100
# 1250000/1250000 [==============================] - 8s 7us/sample - loss: 0.5908 - categorical_accuracy: 0.7843
# Epoch 6/100
# 1250000/1250000 [==============================] - 9s 7us/sample - loss: 0.5844 - categorical_accuracy: 0.7863
# Epoch 7/100
# 1250000/1250000 [==============================] - 10s 8us/sample - loss: 0.5804 - categorical_accuracy: 0.7871
# Epoch 8/100
# 1250000/1250000 [==============================] - 9s 7us/sample - loss: 0.5772 - categorical_accuracy: 0.7881
# Epoch 9/100
# 1250000/1250000 [==============================] - 8s 6us/sample - loss: 0.5742 - categorical_accuracy: 0.7886
# Epoch 10/100
# 1250000/1250000 [==============================] - 7s 6us/sample - loss: 0.5718 - categorical_accuracy: 0.7895
# Epoch 11/100
# 1250000/1250000 [==============================] - 7s 6us/sample - loss: 0.5694 - categorical_accuracy: 0.7900
# Epoch 12/100
# 1250000/1250000 [==============================] - 9s 8us/sample - loss: 0.5686 - categorical_accuracy: 0.7902
# Epoch 13/100
# 1250000/1250000 [==============================] - 9s 7us/sample - loss: 0.5666 - categorical_accuracy: 0.7908
# Epoch 14/100
# 1250000/1250000 [==============================] - 9s 7us/sample - loss: 0.5647 - categorical_accuracy: 0.7914
# Epoch 15/100
# 1250000/1250000 [==============================] - 6s 5us/sample - loss: 0.5631 - categorical_accuracy: 0.7915
# Epoch 16/100
# 1250000/1250000 [==============================] - 4s 3us/sample - loss: 0.5621 - categorical_accuracy: 0.7923
# Epoch 90/100
# 1250000/1250000 [==============================] - 8s 6us/sample - loss: 0.5287 - categorical_accuracy: 0.7968
# Epoch 91/100
# 1250000/1250000 [==============================] - 9s 7us/sample - loss: 0.5284 - categorical_accuracy: 0.7968
# Epoch 92/100
# 1250000/1250000 [==============================] - 8s 7us/sample - loss: 0.5282 - categorical_accuracy: 0.7969
# Epoch 93/100
# 1250000/1250000 [==============================] - 8s 6us/sample - loss: 0.5281 - categorical_accuracy: 0.7966
# Epoch 94/100
# 1250000/1250000 [==============================] - 8s 6us/sample - loss: 0.5280 - categorical_accuracy: 0.7968
# Epoch 95/100
# 1250000/1250000 [==============================] - 7s 5us/sample - loss: 0.5275 - categorical_accuracy: 0.7968
# Epoch 96/100
# 1250000/1250000 [==============================] - 10s 8us/sample - loss: 0.5272 - categorical_accuracy: 0.7967
# Epoch 97/100
# 1250000/1250000 [==============================] - 6s 5us/sample - loss: 0.5270 - categorical_accuracy: 0.7971
# Epoch 98/100
# 1250000/1250000 [==============================] - 8s 7us/sample - loss: 0.5270 - categorical_accuracy: 0.7968
# Epoch 99/100
# 1250000/1250000 [==============================] - 9s 7us/sample - loss: 0.5261 - categorical_accuracy: 0.7970
# Epoch 100/100
# 1250000/1250000 [==============================] - 8s 6us/sample - loss: 0.5268 - categorical_accuracy: 0.7969
# 62500/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
# Plotting loss
plt.plot(10*np.log10(history.history['loss']))
plt.xlim(0,100)
plt.ylabel('Entropia Cruzada (dB)')
plt.grid(color='black', linestyle='dotted')
plt.xlabel('Épocas')
plt.savefig('saved/cnn_maior/error.eps', format='eps')
plt.show()

# %%
# Original picture from testing data
original = np.load('dataset_gray/original/8/arrays/original.npy')
plt.imshow(original, 'gray')

# %%
# Degraded picture
degradada = np.load('dataset_gray/sigma2(7, 7)/arrays/degradada.npy')
plt.imshow(degradada, 'gray')

# %%
original_tf = tf.convert_to_tensor(np.expand_dims(original, axis=2), np.float64)
degradada_tf = tf.convert_to_tensor(np.expand_dims(degradada, axis=2), np.float64)

# %%
# SSIM between original and degraded pictures
tf.image.ssim(original_tf, degradada_tf, max_val=7).numpy()
# Out:
# 0.7746411

# %%
# Restored picture
rest = np.argmax(test_output, axis=1).reshape((original.shape[0] - (janela - 1), original.shape[0] - (janela - 1)))
rest = np.rint(rest)
plt.imshow(rest, cmap = 'gray')
Image.fromarray(32*rest.astype(np.uint8), mode='L').save('saved/cnn_maior/rest.eps')

# %%
# Reshaping original picture for SSIM comparation
original_aux = original[3:253, 3: 253]
plt.imshow(original_aux, cmap = 'gray')

# %%
original_aux_tf = tf.convert_to_tensor(np.expand_dims(original_aux, axis=2), np.float64)
rest_tf = tf.convert_to_tensor(np.expand_dims(rest, axis=2), np.float64)

# %%
# SSIM between original and restored pictures
tf.image.ssim(original_aux_tf, rest_tf, max_val=7).numpy()
# Out:
# 0.8401814

# %%
# Saving model
model.save('saved/cnn_maior/model.h5')
